# %%
# %load_ext sql
import pandas as pd
data=pd.read_csv(r"C:\Users\NICOLE\OneDrive\Desktop\Datathon\Rotman MMA Summer Datathon NWHL.csv")
goal_data=pd.read_csv(r"C:\Users\NICOLE\OneDrive\Desktop\Datathon\goal_data.csv")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
data.head()
# Out:
#    game_date            Home Team     Away Team  Period  Clock  \
# 0  2021/1/23  Minnesota Whitecaps  Boston Pride       1  20:00
# 1  2021/1/23  Minnesota Whitecaps  Boston Pride       1  19:58
# 2  2021/1/23  Minnesota Whitecaps  Boston Pride       1  19:57
# 3  2021/1/23  Minnesota Whitecaps  Boston Pride       1  19:55
# 4  2021/1/23  Minnesota Whitecaps  Boston Pride       1  19:53
#
#    Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 0                  5                  5                0                0
# 1                  5                  5                0                0
# 2                  5                  5                0                0
# 3                  5                  5                0                0
# 4                  5                  5                0                0
#
#            Team  ...          Event X Coordinate  Y Coordinate  Detail 1  \
# ...

# %%
goal_data.head()
# Out:
#    Unnamed: 0  game_date            Home Team          Away Team  Period  \
# 0         387  2021/1/23  Minnesota Whitecaps       Boston Pride       1
# 1         423  2021/1/23  Minnesota Whitecaps       Boston Pride       1
# 2         879  2021/1/23  Minnesota Whitecaps       Boston Pride       2
# 3        2382  2021/1/23       Buffalo Beauts  Connecticut Whale       2
# 4        3052  2021/1/23       Buffalo Beauts  Connecticut Whale       3
#
#    Clock  Home Team Skaters  Away Team Skaters  Home Team Goals  \
# 0   6:42                  5                  5                0
# 1   5:40                  5                  5                0
# 2   8:02                  5                  5                1
# 3  15:54                  5                  5                0
# 4  14:32                  5                  4                0
#
#    Away Team Goals  ... Event X Coordinate Y Coordinate   Detail 1  Detail 2  \
# ...
